# %%
from _model.myModel import mAR
from _preprocessing.addFeatures import logReturn
from _preprocessing.TrainTest import TTS
from sklearn.metrics import mean_squared_error as MSE

import pandas as pd
import numpy as np
import copy

from itertools import product

import torch

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

dataPATH = './Data/raw-TWWI-2011To2021.csv'

rawDF = pd.read_csv(dataPATH)

windowsParams = [30]
lrParams = [0.01]
epochParams = [2000]

allProduct = product(windowsParams, lrParams, epochParams)

for c in allProduct:

    windows, lr, epochs = c[0], c[1], c[2] 

    LR = logReturn()
    LR.fit(df=rawDF['發行量加權股價指數'], windows=windows) 
    x, y = LR.rollingX, LR.rollingY.reshape(len(LR.rollingY), 1)
    x = np.nan_to_num(x, 0)
    model = mAR(input_size=x.shape[1], hidden_size=10)
     

    model.to(device)
    x = torch.Tensor(x)
    y = torch.Tensor(y)
    x = x.to(device)
    y = y.to(device)
        
    tts = TTS()
    tts.fit(X=x, Y=y)
    train_X, train_Y = tts.train_X, tts.train_Y
        
    criterion = torch.nn.MSELoss()
    optimizer = torch.optim.SGD(model.parameters(), lr=lr)
        
    for epoch in range(epochs):
        out = model(train_X)
        optimizer.zero_grad()
            
        loss = criterion(out, train_Y)
        loss.backward()
            
        optimizer.step()
            
        torch.cuda.empty_cache()
            
        if epoch % 100 == 0:
            print (f'Epoch : {epoch:5d}\nLoss: {loss.item()}\n{"="*50}')
        
    y_pred_lr = model(x)
    y_pred_lr = y_pred_lr.cpu().detach().numpy().reshape(-1)
    y_pred = LR.backwardR(logR=y_pred_lr, pred=True)
    
    ts = len(tts.test_X)
    mse = MSE(y_true=rawDF['發行量加權股價指數'].values[-ts:], y_pred=y_pred[-ts:])
        
    print(mse)
# Out:
# Epoch :     0
# Loss: 0.0015511141391471028
# ==================================================
# Epoch :   100
# Loss: 9.440840221941471e-05
# ==================================================
# Epoch :   200
# Loss: 8.546240133000538e-05
# ==================================================
# Epoch :   300
# Loss: 8.435041672782972e-05
# ==================================================
# Epoch :   400
# Loss: 8.40187567519024e-05
# ==================================================
# Epoch :   500
# Loss: 8.379112841794267e-05
# ==================================================
# Epoch :   600
# Loss: 8.361756044905633e-05
# ==================================================
# Epoch :   700
# Loss: 8.351918222615495e-05
# ==================================================
# Epoch :   800
# Loss: 8.344495290657505e-05
# ==================================================
# Epoch :   900
# Loss: 8.337400504387915e-05
# ==================================================
# Epoch :  1000
# Loss: 8.333064033649862e-05
# ==================================================
# Epoch :  1100
# Loss: 8.330521086463705e-05
# ==================================================
# Epoch :  1200
# Loss: 8.328711555805057e-05
# ==================================================
# Epoch :  1300
# Loss: 8.326570969074965e-05
# ==================================================
# Epoch :  1400
# Loss: 8.32256700959988e-05
# ==================================================
# Epoch :  1500
# Loss: 8.318837353726849e-05
# ==================================================
# Epoch :  1600
# Loss: 8.315794548252597e-05
# ==================================================
# Epoch :  1700
# Loss: 8.312088175443932e-05
# ==================================================
# Epoch :  1800
# Loss: 8.307949610752985e-05
# ==================================================
# Epoch :  1900
# Loss: 8.305370283778757e-05
# ==================================================
# 18782.249274976075
